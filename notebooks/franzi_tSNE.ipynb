# %%
import pandas as pd
from sklearn.manifold import TSNE

# %%
data = pd.read_csv('../features_for_quiz/houses/classes.csv')

# %%
data
# Out:
#               class  outcast  climate  empathy  fighting  honor  connections  \
# 0          Wildling        1        0        1         5      2            1
# 1            Outlaw        1        1        1         5      1            1
# 2          Dothraki        0        2        1         5      2            1
# 3     Night's Watch        0        0        3         4      5            2
# 4           Soldier        0        1        3         4      4            2
# 5     Foreign Noble        0        2        3         2      2            4
# 6   Foreign Peasant        1        2        3         3      1            1
# 7             Noble        0        1        3         3      3            4
# 8           Peasant        1        1        3         2      1            1
# 9      House Bolton        0        1        1         4      1            3
# 10      House Stark        0        0        5         4      5            3
# 11      House Arryn        0        1        3         3      3            3
# 12    House Greyjoy        0        0        2         3      2            1
# 13       House Frey        0        1        1         1      1            1
# 14      House Tully        0        1        3         3      3            3
# 15  House Lannister        0        2        2         4      3            5
# 16     House Tyrell        0        2        4         3      3            4
# 17    House Martell        0        2        3         4      3            3
# 18  House Baratheon        0        1        3         4      4            3
# 19  House Targaryen        0        2        4         5      4            4
#
#     unyielding
# 0            4
# 1            3
# 2            4
# 3            4
# 4            4
# 5            2
# 6            1
# 7            2
# 8            1
# 9            2
# 10           4
# 11           4
# 12           5
# 13           1
# 14           3
# 15           4
# 16           3
# 17           4
# 18           4
# 19           5

# %%
X = data.drop(columns='class')
y = data['class']

# %%
tsne = TSNE()
tsne.fit()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import learning_curve
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from scipy import stats
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("raw_data/20231128_only_deaths_ep_weights.csv")

# %%
df = df[df['allegiance'].map(df['allegiance'].value_counts()) > 30]

# %%
df = df[df['killer'].map(df['killer'].value_counts()) > 30]

# %%
df = df[df['killers_house'].map(df['killers_house'].value_counts()) > 30]

# %%
df = df[df['location'].map(df['location'].value_counts()) > 30]

# %%
df = df[df['method'].map(df['method'].value_counts()) > 30]

# %%
df
# Out:
#       Unnamed: 0                      allegiance  \
# 45            45                       Smallfolk
# 82            82                       Free Folk
# 149          149  House Baratheon of Dragonstone
# 151          151  House Baratheon of Dragonstone
# 164          164  House Baratheon of Dragonstone
# ...          ...                             ...
# 2218        2218                            None
# 2219        2219                            None
# 2220        2220                            None
# 2221        2221                            None
# 2222        2222                            None
#
#                                    killer                      killers_house  \
# 45                             Arya Stark                        House Stark
# 82                  Night's Watch brother                      Night's Watch
# 149   Baratheon of King's Landing soldier  House Baratheon of King's Landing
# 151   Baratheon of King's Landing soldier  House Baratheon of King's Landing
# 164   Baratheon of King's Landing soldier  House Baratheon of King's Landing
# ...                                   ...                                ...
# 2218                   Daenerys Targaryen                    House Targaryen
# 2219                   Daenerys Targaryen                    House Targaryen
# 2220                   Daenerys Targaryen                    House Targaryen
# 2221                   Daenerys Targaryen                    House Targaryen
# 2222                   Daenerys Targaryen                    House Targaryen
#
#              location               method                              name  \
# 45     King's Landing                Sword                         Stableboy
# 82    Beyond the Wall                Arrow                          Wildling
# 149    King's Landing                Sword  Baratheon of Dragonstone soldier
# 151    King's Landing                Sword  Baratheon of Dragonstone soldier
# 164    King's Landing                Sword  Baratheon of Dragonstone soldier
# ...               ...                  ...                               ...
# 2218   King's Landing  Dragonfire (Dragon)            King's Landing Citizen
# 2219   King's Landing  Dragonfire (Dragon)            King's Landing Citizen
# 2220   King's Landing  Dragonfire (Dragon)            King's Landing Citizen
# 2221   King's Landing  Dragonfire (Dragon)            King's Landing Citizen
# 2222   King's Landing  Dragonfire (Dragon)            King's Landing Citizen
#
#       episode_global_num  weights_simple
# 45                     8        0.999550
# 82                    16        0.952338
# 149                   19        0.973921
# 151                   19        0.973921
# 164                   19        0.973921
# ...                  ...             ...
# 2218                  72        0.895234
# 2219                  72        0.895234
# 2220                  72        0.895234
# 2221                  72        0.895234
# 2222                  72        0.895234
#
# [1360 rows x 9 columns]

# %%
df = df.drop(columns=["Unnamed: 0",'name'], axis=1)

# %%
y = df["episode_global_num"]
y = y.to_frame(name="episode_global_num")
y.head()
# Out:
#      episode_global_num
# 45                    8
# 82                   16
# 149                  19
# 151                  19
# 164                  19

# %%
X = df
X = X.drop(columns = ["episode_global_num"], axis=1)
X.head()
# Out:
#                          allegiance                               killer  \
# 45                        Smallfolk                           Arya Stark
# 82                        Free Folk                Night's Watch brother
# 149  House Baratheon of Dragonstone  Baratheon of King's Landing soldier
# 151  House Baratheon of Dragonstone  Baratheon of King's Landing soldier
# 164  House Baratheon of Dragonstone  Baratheon of King's Landing soldier
#
#                          killers_house         location method  weights_simple
# 45                         House Stark   King's Landing  Sword        0.999550
# 82                       Night's Watch  Beyond the Wall  Arrow        0.952338
# 149  House Baratheon of King's Landing   King's Landing  Sword        0.973921
# 151  House Baratheon of King's Landing   King's Landing  Sword        0.973921
# 164  House Baratheon of King's Landing   King's Landing  Sword        0.973921

# %%
num_transformer = Pipeline([('standard_scaler', StandardScaler())])

cat_transformer = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

preprocessor = ColumnTransformer([
    ('num_transformer', num_transformer, ["weights_simple"]),
    ('cat_transformer', cat_transformer, ['allegiance','killer','killers_house','location','method'])
])

# %%
X_train = pd.DataFrame(preprocessor.fit_transform(X_train),
            columns=preprocessor.get_feature_names_out())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/game-of-thrones-survival/lib/python3.10/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/.pyenv/versions/3.10.6/envs/game-of-thrones-survival/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.10.6/envs/game-of-thrones-survival/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'allegiance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/game-of-thrones-survival/lib/python3.10/site-packages/sklearn/utils/__init__.py:447, in _get_column_indices(X, key)
#     446 for col in columns:
# --> 447     col_idx = all_columns.get_loc(col)
#     448     if not isinstance(col_idx, numbers.Integral):
#
# File ~/.pyenv/versions/3.10.6/envs/game-of-thrones-survival/lib/python3.10/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#
# KeyError: 'allegiance'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 X_train = pd.DataFrame(preprocessor.fit_transform(X_train),
#       2             columns=preprocessor.get_feature_names_out())
#
# File ~/.pyenv/versions/3.10.6/envs/game-of-thrones-survival/lib/python3.10/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~/.pyenv/versions/3.10.6/envs/game-of-thrones-survival/lib/python3.10/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/game-of-thrones-survival/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py:751, in ColumnTransformer.fit_transform(self, X, y)
#     749 self._check_n_features(X, reset=True)
#     750 self._validate_transformers()
# --> 751 self._validate_column_callables(X)
#     752 self._validate_remainder(X)
#     754 result = self._fit_transform(X, y, _fit_transform_one)
#
# File ~/.pyenv/versions/3.10.6/envs/game-of-thrones-survival/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py:459, in ColumnTransformer._validate_column_callables(self, X)
#     457         columns = columns(X)
#     458     all_columns.append(columns)
# --> 459     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     461 self._columns = all_columns
#     462 self._transformer_to_input_indices = transformer_to_input_indices
#
# File ~/.pyenv/versions/3.10.6/envs/game-of-thrones-survival/lib/python3.10/site-packages/sklearn/utils/__init__.py:455, in _get_column_indices(X, key)
#     452             column_indices.append(col_idx)
#     454     except KeyError as e:
# --> 455         raise ValueError("A given column is not a column of the dataframe") from e
#     457     return column_indices
#     458 else:
#
# ValueError: A given column is not a column of the dataframe

# %%
X_train.columns
# Out:
# Index(['num_transformer__weights_simple',
#        'cat_transformer__allegiance_Faith Militant',
#        'cat_transformer__allegiance_Free Folk',
#        'cat_transformer__allegiance_House Baratheon of Dragonstone',
#        'cat_transformer__allegiance_House Bolton',
#        'cat_transformer__allegiance_House Frey',
#        'cat_transformer__allegiance_House Greyjoy',
#        'cat_transformer__allegiance_House Lannister',
#        'cat_transformer__allegiance_House Stark',
#        'cat_transformer__allegiance_House Targaryen',
#        'cat_transformer__allegiance_Night's Watch',
#        'cat_transformer__allegiance_None',
#        'cat_transformer__allegiance_Smallfolk',
#        'cat_transformer__allegiance_Sons of the Harpy',
#        'cat_transformer__killer_Arya Stark',
#        'cat_transformer__killer_Baratheon of King's Landing soldier',
#        'cat_transformer__killer_Bolton soldier',
#        'cat_transformer__killer_Cersei Lannister',
#        'cat_transformer__killer_Daenerys Targaryen',
#        'cat_transformer__killer_Dothraki man',
#        'cat_transformer__killer_Jon Snow',
#        'cat_transformer__killer_Night's Watch brother',
#        'cat_transformer__killer_Sons of the Harpy agent',
#        'cat_transformer__killer_Stark Soldier',
#        'cat_transformer__killer_Wight',
#        'cat_transformer__killers_house_House Baratheon of King's Landing',
#        'cat_transformer__killers_house_House Bolton',
#        'cat_transformer__killers_house_House Lannister',
#        'cat_transformer__killers_house_House Stark',
#        'cat_transformer__killers_house_House Targaryen',
#        'cat_transformer__killers_house_Night's Watch',
#        'cat_transformer__killers_house_Sons of the Harpy',
#        'cat_transformer__killers_house_White Walkers',
#        'cat_transformer__location_Beyond the Wall',
#        'cat_transformer__location_King's Landing',
#        'cat_transformer__location_Meereen',
#        'cat_transformer__location_Roseroad',
#        'cat_transformer__location_The Twins',
#        'cat_transformer__location_Winterfell', 'cat_transformer__method_Arrow',
#        'cat_transformer__method_Dragonfire (Dragon)',
#        'cat_transformer__method_Poison', 'cat_transformer__method_Sword',
#        'cat_transformer__method_Wildfire'],
#       dtype='object')

# %%
model = LinearRegression()
model.fit(X_train,y_train)
cv_results = cross_validate(model, X_train, y_train, cv=5, scoring=('r2', 'neg_mean_squared_error'))
test = cv_results["test_r2"].mean()
test
# Out:
# -6.839459326519043e+21
